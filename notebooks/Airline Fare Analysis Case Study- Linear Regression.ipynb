# %% [markdown]
# # Description:
# Airfares and passengers for U.S. Domestic Routes
# for 4th Quarter of 2002.
#
#
# # Variables/Columns
#
# City1   1-3
#
# City2   5-7
#
# Average Fare    11-17
#
# Distance      20-23
#
# Average weekly passengers   26-33
#
# market leading airline    36-37
#
# market share     40-45
#
# Average fare    48-54
#
# Low price airline   57-58
#
# market share    61-66
#
# price     69-75

# %% [markdown]
# # Source:
# U.S. Department of Transportation
#
# # 1. Reading Source File and Checking Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading source file
file=pd.read_csv("http://users.stat.ufl.edu/~winner/data/airq402.dat", sep='\s+'  , engine='python')

# %%
# Adding colunm names as mentioned in data file
file.columns = ['City1', 'City2', 'Average Flight Fare', 'Distance','Average Weekly Passengers','Market Leading Airline (MLA)',
               'Market Share MLA', 'Average MLA Fare', 'Low Price Airline (LPA)', 'Market Share LPA', 'Average LPA Fare']

# %%
file.head()
# Out:
#   City1 City2  Average Flight Fare  Distance  Average Weekly Passengers  \
# 0   CAK   MCO               122.47       860                     276.84
# 1   ALB   ATL               214.42       852                     215.76
# 2   ALB   BWI                69.40       288                     606.84
# 3   ALB   ORD               158.13       723                     313.04
# 4   ALB   FLL               135.17      1204                     199.02
#
#   Market Leading Airline (MLA)  Market Share MLA  Average MLA Fare  \
# 0                           FL             75.10            123.09
# 1                           DL             78.89            223.98
# 2                           WN             96.97             68.86
# 3                           UA             39.79            161.36
# 4                           WN             40.68            137.97
#
#   Low Price Airline (LPA)  Market Share LPA  Average LPA Fare
# 0                      DL             17.23            118.94
# 1                      CO              2.77            167.12
# 2                      WN             96.97             68.86
# 3                      WN             15.34            145.42
# 4                      DL             17.09            127.69

# %% [markdown]
# # 2. DATA CLEANING

# %%
# getting total number of rows and column in the dataframe
print(f" Shape of the dataframe = {file.shape}")
totalrows=file.shape[0]
print(f" Total number of rows in the dataset =  {totalrows}")
# Out:
#  Shape of the dataframe = (999, 11)
#  Total number of rows in the dataset =  999

# %%
# Checking Null colunms
file_nullcols = file.isnull().sum()
file_nullcols

# No null values are found
# Out:
# City1                           0
# City2                           0
# Average Flight Fare             0
# Distance                        0
# Average Weekly Passengers       0
# Market Leading Airline (MLA)    0
# Market Share MLA                0
# Average MLA Fare                0
# Low Price Airline (LPA)         0
# Market Share LPA                0
# Average LPA Fare                0
# dtype: int64

# %%
# Checking data type of each colunm to check if any type needs to be changed
file.dtypes
# Out:
# City1                            object
# City2                            object
# Average Flight Fare             float64
# Distance                          int64
# Average Weekly Passengers       float64
# Market Leading Airline (MLA)     object
# Market Share MLA                float64
# Average MLA Fare                float64
# Low Price Airline (LPA)          object
# Market Share LPA                float64
# Average LPA Fare                float64
# dtype: object

# %%
# Checking basic details of the data
file.describe()
# Out:
#        Average Flight Fare     Distance  Average Weekly Passengers  \
# count           999.000000   999.000000                 999.000000
# mean            163.424374  1057.502503                 672.527107
# std              55.371544   643.307320                 766.863056
# min              50.520000   108.000000                 181.410000
# 25%             126.025000   554.000000                 257.115000
# 50%             161.360000   919.000000                 404.780000
# 75%             197.435000  1455.000000                 770.265000
# max             401.230000  2724.000000                8950.760000
#
#        Market Share MLA  Average MLA Fare  Market Share LPA  Average LPA Fare
# count        999.000000        999.000000        999.000000        999.000000
# mean          60.118519        166.703233         34.515806        143.225285
# std           19.374859         62.666775         27.087067         47.241860
# min           17.680000         50.520000          1.060000         49.610000
# 25%           46.510000        124.120000         13.190000        113.825000
# 50%           59.060000        161.440000         26.120000        137.830000
# 75%           73.520000        203.105000         52.950000        168.540000
# max          100.000000        490.030000        100.000000        387.940000

# %%
# Mean of distance, Average Weekly Passengers, Market share is above median
#These prima facie seem to have outliers

# %% [markdown]
# # 3. EDA

# %% [markdown]
# ## 3.1 Univariate Analysis

# %%
plt.figure(figsize=(20,6))
plt.subplot(1, 3, 1)
plt.title('Average Flight Fare')
sns.distplot(file['Average Flight Fare'],color='green')

# subplot 2
plt.subplot(1, 3, 2)
plt.title('Distance')
sns.distplot(file['Distance'],color='blue')

# subplot 3l
plt.subplot(1, 3, 3)
plt.title('Average Weekly Passengers')
sns.distplot(file['Average Weekly Passengers'],color='red')

plt.figure(figsize=(20,6))
plt.subplot(1, 3, 1)
plt.title('Average Flight Fare')
sns.boxplot(file['Average Flight Fare'],orient='vertical',color='green')

# subplot 2
plt.subplot(1, 3, 2)
plt.title('Distance')
sns.boxplot(file['Distance'],orient='vertical',color='blue')

# subplot 3
plt.subplot(1, 3, 3)
plt.title('Average Weekly Passengers')
sns.boxplot(file['Average Weekly Passengers'],orient='vertical',color='red')


plt.show()
# Out:
# /tmp/ipykernel_5209/3414253163.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(file['Average Flight Fare'],color='green')
# /tmp/ipykernel_5209/3414253163.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(file['Distance'],color='blue')
# /tmp/ipykernel_5209/3414253163.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(file['Average Weekly Passengers'],color='red')

# %% [markdown]
# ##### Most of the flight fare lie between 100 to 300 with some outliers
# ##### Average distance ranges between 500 to 2500
# ##### Most of the time Average Weekly Passenger numer is less than 2000 but there are large number of outliers

# %%
plt.figure(figsize=(20,6))
plt.subplot(1, 4, 1)
plt.title('Market Share MLA')
sns.distplot(file['Market Share MLA'],color='green')

# subplot 2
plt.subplot(1, 4, 2)
plt.title('Average MLA Fare')
sns.distplot(file['Average MLA Fare'],color='blue')

# subplot 3
plt.subplot(1, 4, 3)
plt.title('Market Share LPA')
sns.distplot(file['Market Share LPA'],color='red')

# subplot 4
plt.subplot(1, 4, 4)
plt.title('Average LPA Fare')
sns.distplot(file['Average LPA Fare'],color='red')


plt.figure(figsize=(20,6))
plt.subplot(1, 4, 1)
plt.title('Market Share MLA')
sns.boxplot(file['Market Share MLA'],orient='vertical',color='green')

# subplot 2
plt.subplot(1, 4, 2)
plt.title('Average MLA Fare')
sns.boxplot(file['Average MLA Fare'],orient='vertical',color='blue')

# subplot 3
plt.subplot(1, 4, 3)
plt.title('Market Share LPA')
sns.boxplot(file['Market Share LPA'],orient='vertical',color='red')

# subplot 4
plt.subplot(1, 4, 4)
plt.title('Average LPA Fare')
sns.boxplot(file['Average LPA Fare'],orient='vertical',color='red')



plt.show()
# Out:
# /tmp/ipykernel_5209/2198768784.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(file['Market Share MLA'],color='green')
# /tmp/ipykernel_5209/2198768784.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(file['Average MLA Fare'],color='blue')
# /tmp/ipykernel_5209/2198768784.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(file['Market Share LPA'],color='red')
# /tmp/ipykernel_5209/2198768784.py:19: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(file['Average LPA Fare'],color='red')

# %% [markdown]
# ##### Average fare of both Market Leader and Low Price Airline range from 100 to 300 with some outliers
# ##### Market Leader has 40 to 80 percent market share on most routes
# ##### Lower Price airline has less than 40 percent market share on most of the routes

# %%
fig, ax = plt.subplots(figsize=(20,8))
width = len(file['Market Leading Airline (MLA)'].unique()) + 6
fig.set_size_inches(width , 8)
ax=sns.countplot(data = file, x= 'Market Leading Airline (MLA)') 



for p in ax.patches: 
    ax.annotate(str((np.round(p.get_height()/len(file)*100,decimals=2)))+'%', (p.get_x()+p.get_width()/2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')

# %% [markdown]
# ##### WN followed by DL happens to be market leader airline on most of the routes

# %%
fig, ax = plt.subplots(figsize=(20,8))
width = len(file['Low Price Airline (LPA)'].unique()) + 6
fig.set_size_inches(width , 8)
ax=sns.countplot(data = file, x= 'Low Price Airline (LPA)') 



for p in ax.patches: 
    ax.annotate(str((np.round(p.get_height()/len(file)*100,decimals=2)))+'%', (p.get_x()+p.get_width()/2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')

# %%
##### WN followed by DL happens to be the low price airline on most routes

# %% [markdown]
# ## 3.2. Bivariate Analysis

# %%
corr = file[['Average Flight Fare', 'Distance','Average Weekly Passengers','Market Share MLA', 'Average MLA Fare','Market Share LPA', 'Average LPA Fare']].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_737bd_row0_col0, #T_737bd_row1_col1, #T_737bd_row2_col2, #T_737bd_row3_col3, #T_737bd_row4_col4, #T_737bd_row5_col5, #T_737bd_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_737bd_row0_col1, #T_737bd_row6_col1 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_737bd_row0_col2 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_737bd_row0_col3 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_737bd_row0_col4, #T_737bd_row4_col0 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_737bd_row0_col5 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_737bd_row0_col6 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_737bd_row1_col0, #T_737bd_row4_col1 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_737bd_row1_col2 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_737bd_row1_col3, #T_737bd_row3_col1, #T_737bd_row3_col6, #T_737bd_row4_col5, #T_737bd_row5_col0, #T_737bd_row5_col4, #T_737bd_row6_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_737bd_row1_col4 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_737bd_row1_col5 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_737bd_row1_col6 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_737bd_row2_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_737bd_row2_col1 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_737bd_row2_col3 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_737bd_row2_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_737bd_row2_col5 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_737bd_row2_col6 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_737bd_row3_col0, #T_737bd_row5_col2 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_737bd_row3_col2 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_737bd_row3_col4 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_737bd_row3_col5 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_737bd_row4_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_737bd_row4_col3 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_737bd_row4_col6 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_737bd_row5_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_737bd_row5_col3 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_737bd_row5_col6 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_737bd_row6_col0 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_737bd_row6_col3 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_737bd_row6_col4 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_737bd_row6_col5 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_737bd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_737bd_level0_col0" class="col_heading level0 col0" >Average Flight Fare</th>
#       <th id="T_737bd_level0_col1" class="col_heading level0 col1" >Distance</th>
#       <th id="T_737bd_level0_col2" class="col_heading level0 col2" >Average Weekly Passengers</th>
#       <th id="T_737bd_level0_col3" class="col_heading level0 col3" >Market Share MLA</th>
#       <th id="T_737bd_level0_col4" class="col_heading level0 col4" >Average MLA Fare</th>
#       <th id="T_737bd_level0_col5" class="col_heading level0 col5" >Market Share LPA</th>
#       <th id="T_737bd_level0_col6" class="col_heading level0 col6" >Average LPA Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_737bd_level0_row0" class="row_heading level0 row0" >Average Flight Fare</th>
#       <td id="T_737bd_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_737bd_row0_col1" class="data row0 col1" >0.586869</td>
#       <td id="T_737bd_row0_col2" class="data row0 col2" >-0.126517</td>
#       <td id="T_737bd_row0_col3" class="data row0 col3" >-0.233805</td>
#       <td id="T_737bd_row0_col4" class="data row0 col4" >0.981448</td>
#       <td id="T_737bd_row0_col5" class="data row0 col5" >-0.458072</td>
#       <td id="T_737bd_row0_col6" class="data row0 col6" >0.866348</td>
#     </tr>
#     <tr>
#       <th id="T_737bd_level0_row1" class="row_heading level0 row1" >Distance</th>
#       <td id="T_737bd_row1_col0" class="data row1 col0" >0.586869</td>
#       <td id="T_737bd_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_737bd_row1_col2" class="data row1 col2" >-0.090433</td>
#       <td id="T_737bd_row1_col3" class="data row1 col3" >-0.531229</td>
#       <td id="T_737bd_row1_col4" class="data row1 col4" >0.563765</td>
#       <td id="T_737bd_row1_col5" class="data row1 col5" >-0.367190</td>
#       <td id="T_737bd_row1_col6" class="data row1 col6" >0.583011</td>
#     </tr>
#     <tr>
#       <th id="T_737bd_level0_row2" class="row_heading level0 row2" >Average Weekly Passengers</th>
#       <td id="T_737bd_row2_col0" class="data row2 col0" >-0.126517</td>
#       <td id="T_737bd_row2_col1" class="data row2 col1" >-0.090433</td>
#       <td id="T_737bd_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_737bd_row2_col3" class="data row2 col3" >-0.067450</td>
#       <td id="T_737bd_row2_col4" class="data row2 col4" >-0.101279</td>
#       <td id="T_737bd_row2_col5" class="data row2 col5" >0.034699</td>
#       <td id="T_737bd_row2_col6" class="data row2 col6" >-0.142575</td>
#     </tr>
#     <tr>
#       <th id="T_737bd_level0_row3" class="row_heading level0 row3" >Market Share MLA</th>
#       <td id="T_737bd_row3_col0" class="data row3 col0" >-0.233805</td>
#       <td id="T_737bd_row3_col1" class="data row3 col1" >-0.531229</td>
#       <td id="T_737bd_row3_col2" class="data row3 col2" >-0.067450</td>
#       <td id="T_737bd_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_737bd_row3_col4" class="data row3 col4" >-0.220456</td>
#       <td id="T_737bd_row3_col5" class="data row3 col5" >0.306454</td>
#       <td id="T_737bd_row3_col6" class="data row3 col6" >-0.307430</td>
#     </tr>
#     <tr>
#       <th id="T_737bd_level0_row4" class="row_heading level0 row4" >Average MLA Fare</th>
#       <td id="T_737bd_row4_col0" class="data row4 col0" >0.981448</td>
#       <td id="T_737bd_row4_col1" class="data row4 col1" >0.563765</td>
#       <td id="T_737bd_row4_col2" class="data row4 col2" >-0.101279</td>
#       <td id="T_737bd_row4_col3" class="data row4 col3" >-0.220456</td>
#       <td id="T_737bd_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_737bd_row4_col5" class="data row4 col5" >-0.472264</td>
#       <td id="T_737bd_row4_col6" class="data row4 col6" >0.826423</td>
#     </tr>
#     <tr>
#       <th id="T_737bd_level0_row5" class="row_heading level0 row5" >Market Share LPA</th>
#       <td id="T_737bd_row5_col0" class="data row5 col0" >-0.458072</td>
#       <td id="T_737bd_row5_col1" class="data row5 col1" >-0.367190</td>
#       <td id="T_737bd_row5_col2" class="data row5 col2" >0.034699</td>
#       <td id="T_737bd_row5_col3" class="data row5 col3" >0.306454</td>
#       <td id="T_737bd_row5_col4" class="data row5 col4" >-0.472264</td>
#       <td id="T_737bd_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_737bd_row5_col6" class="data row5 col6" >-0.239552</td>
#     </tr>
#     <tr>
#       <th id="T_737bd_level0_row6" class="row_heading level0 row6" >Average LPA Fare</th>
#       <td id="T_737bd_row6_col0" class="data row6 col0" >0.866348</td>
#       <td id="T_737bd_row6_col1" class="data row6 col1" >0.583011</td>
#       <td id="T_737bd_row6_col2" class="data row6 col2" >-0.142575</td>
#       <td id="T_737bd_row6_col3" class="data row6 col3" >-0.307430</td>
#       <td id="T_737bd_row6_col4" class="data row6 col4" >0.826423</td>
#       <td id="T_737bd_row6_col5" class="data row6 col5" >-0.239552</td>
#       <td id="T_737bd_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Average Flight fare is most corelated to fare of market leader and low performing flight

# %%
plt.figure(figsize=(20, 12))
plt.subplot(1,2,1)
sns.boxplot(x = 'Market Leading Airline (MLA)', y = 'Average Flight Fare', data = file)
plt.subplot(1,2,2)
sns.boxplot(x = 'Low Price Airline (LPA)', y = 'Average Flight Fare', data = file)
# Out:
# <Axes: xlabel='Low Price Airline (LPA)', ylabel='Average Flight Fare'>

# %% [markdown]
# ##### Most flights have comparable median flight fare with some having very low values</br>Flight fare of market leading airline and Low Price airline seem to fall in similar range

# %% [markdown]
# # 4. Multivariate Regression and Scatter Plot

# %% [markdown]
# ## 4.1. Scatter Plot

# %%
sns.pairplot(file, y_vars='Average Flight Fare', x_vars=["Distance", "Average Weekly Passengers",
                                                       'Market Share MLA', 'Average MLA Fare','Market Share LPA','Average LPA Fare'
                                                        ])
plt.show()

# %% [markdown]
# ##### Variabes need to be scaled before further analysis

# %% [markdown]
# ##### Transformation seems unnecessary as most data points don't show any clear trend with Average flight Fare.</br>Still checkking effect of log transformation on the data set

# %%
# Log Transformation of independent variables
D1 = np.log(file['Distance'])
D2 = np.log(file['Average Weekly Passengers'])
D3 = np.log(file['Market Share MLA'])
D4 = np.log(file['Average MLA Fare'])
D5 = np.log(file['Market Share LPA'])
D6 = np.log(file['Average LPA Fare'])

# %%
plt.figure(figsize=(20,6))
plt.subplot(1, 2, 1)
plt.title('Flight Fare vs Log(Distance)')
plt.scatter( D1, file['Average Flight Fare'])
plt.xlabel('Log(Distance)')
plt.ylabel('Flight Fare')


plt.figure(figsize=(20,6))
plt.subplot(1, 2, 2)
plt.title('Flight Fare vs Log(Average Weekly Passengers)')
plt.scatter( D2, file['Average Flight Fare'])
plt.xlabel('Log(Average Weekly Passengers)')
plt.ylabel('Flight Fare')


plt.show()
